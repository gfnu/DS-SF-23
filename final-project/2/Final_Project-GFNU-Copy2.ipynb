# %%
import os
import numpy as np
import pandas as pd

userhome = os.path.expanduser('~')
df = pd.read_csv(os.path.join(userhome,'Desktop','DS-SF-23','lending-club-loan-data','loan.csv'), index_col = 'id', low_memory=False)
#df.head(20)

# %%
df.corr()
# Out:
#                              member_id  loan_amnt  funded_amnt  \
# member_id                     1.000000   0.064461     0.066754
# loan_amnt                     0.064461   1.000000     0.999263
# funded_amnt                   0.066754   0.999263     1.000000
# funded_amnt_inv               0.072308   0.997115     0.998025
# int_rate                     -0.142205   0.145023     0.145160
# installment                   0.026036   0.944977     0.946005
# annual_inc                    0.034146   0.332698     0.332466
# dti                           0.067824   0.020675     0.021075
# delinq_2yrs                   0.049904  -0.000159     0.000151
# inq_last_6mths               -0.127257  -0.034168    -0.034711
# mths_since_last_delinq       -0.008682  -0.038080    -0.038117
# mths_since_last_record       -0.158700  -0.010734    -0.010811
# open_acc                      0.088838   0.198906     0.199387
# pub_rec                       0.080788  -0.081177    -0.080836
# ...

# %%
# %matplotlib inline
df.annual_inc.plot(kind='b')

# %%
df[range(0,20)].head(10)
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1077430    1314167     2500.0       2500.0           2500.0   60 months
# 1077175    1313524     2400.0       2400.0           2400.0   36 months
# 1076863    1277178    10000.0      10000.0          10000.0   36 months
# 1075358    1311748     3000.0       3000.0           3000.0   60 months
# 1075269    1311441     5000.0       5000.0           5000.0   36 months
# 1069639    1304742     7000.0       7000.0           7000.0   60 months
# 1072053    1288686     3000.0       3000.0           3000.0   36 months
# 1071795    1306957     5600.0       5600.0           5600.0   60 months
# 1071570    1306721     5375.0       5375.0           5350.0   60 months
#
#          int_rate  installment grade sub_grade                  emp_title  \
# id
# 1077501     10.65       162.87     B        B2                        NaN
# ...

# %%
df.verification_status.unique()
# Out:
# array(['Verified', 'Source Verified', 'Not Verified'], dtype=object)

# %%
df.drop(['desc','purpose'], axis=1,inplace=True)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a4642092433> in <module>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
#df.drop(['url','policy_code'], axis = 1, inplace = True)

# %%
df[range(20,35)].head(3)
# Out:
#                         title zip_code addr_state    dti  delinq_2yrs  \
# id
# 1077501              Computer    860xx         AZ  27.65          0.0
# 1077430                  bike    309xx         GA   1.00          0.0
# 1077175  real estate business    606xx         IL   8.72          0.0
#
#         earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# id
# 1077501         Jan-1985             1.0                     NaN
# 1077430         Apr-1999             5.0                     NaN
# 1077175         Nov-2001             2.0                     NaN
#
#          mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 1077501                     NaN       3.0      0.0    13648.0        83.7
# 1077430                     NaN       3.0      0.0     1687.0         9.4
# 1077175                     NaN       2.0      0.0     2956.0        98.5
#
#          total_acc initial_list_status
# id
# 1077501        9.0                   f
# ...

# %%
df[range(35,50)].head(3)
# Out:
#          out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# id
# 1077501        0.0            0.0  5861.071414          5831.78
# 1077430        0.0            0.0  1008.710000          1008.71
# 1077175        0.0            0.0  3003.653644          3003.65
#
#          total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# id
# 1077501          5000.00         861.07                 0.0        0.00
# 1077430           456.46         435.17                 0.0      117.08
# 1077175          2400.00         603.65                 0.0        0.00
#
#          collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# id
# 1077501                     0.00     Jan-2015           171.62          NaN
# 1077430                     1.11     Apr-2013           119.66          NaN
# 1077175                     0.00     Jun-2014           649.91          NaN
#
#         last_credit_pull_d  collections_12_mths_ex_med  \
# id
# ...

# %%
df[range(50,60)].head(13)
# Out:
#          policy_code application_type  annual_inc_joint  dti_joint  \
# id
# 1077501          1.0       INDIVIDUAL               NaN        NaN
# 1077430          1.0       INDIVIDUAL               NaN        NaN
# 1077175          1.0       INDIVIDUAL               NaN        NaN
# 1076863          1.0       INDIVIDUAL               NaN        NaN
# 1075358          1.0       INDIVIDUAL               NaN        NaN
# 1075269          1.0       INDIVIDUAL               NaN        NaN
# 1069639          1.0       INDIVIDUAL               NaN        NaN
# 1072053          1.0       INDIVIDUAL               NaN        NaN
# 1071795          1.0       INDIVIDUAL               NaN        NaN
# 1071570          1.0       INDIVIDUAL               NaN        NaN
# 1070078          1.0       INDIVIDUAL               NaN        NaN
# 1069908          1.0       INDIVIDUAL               NaN        NaN
# 1064687          1.0       INDIVIDUAL               NaN        NaN
#
# ...

# %%
df[range(60,73)].head(13)
# Out:
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# id
# 1077501          NaN          NaN                 NaN           NaN      NaN
# 1077430          NaN          NaN                 NaN           NaN      NaN
# 1077175          NaN          NaN                 NaN           NaN      NaN
# 1076863          NaN          NaN                 NaN           NaN      NaN
# 1075358          NaN          NaN                 NaN           NaN      NaN
# 1075269          NaN          NaN                 NaN           NaN      NaN
# 1069639          NaN          NaN                 NaN           NaN      NaN
# 1072053          NaN          NaN                 NaN           NaN      NaN
# 1071795          NaN          NaN                 NaN           NaN      NaN
# 1071570          NaN          NaN                 NaN           NaN      NaN
# 1070078          NaN          NaN                 NaN           NaN      NaN
# ...

# %%
df.loan_status.unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', 'Issued'], dtype=object)

# %%
df.total_bal_il.isnull().sum()
# Out:
# 866007

# %%
df.columns

df.drop(['member_id','emp_title','home_ownership','verification_status', 'u'issue_d','u'loan_status','u'url','u'desc','u'purpose','u'title','u'zip_code',''], axis=1,inplace=True)
# Out:
# Index([u'member_id', u'loan_amnt', u'funded_amnt', u'funded_amnt_inv', u'term',
#        u'int_rate', u'installment', u'grade', u'sub_grade', u'emp_title',
#        u'emp_length', u'home_ownership', u'annual_inc', u'verification_status',
#        u'issue_d', u'loan_status', u'pymnt_plan', u'url', u'desc', u'purpose',
#        u'title', u'zip_code', u'addr_state', u'dti', u'delinq_2yrs',
#        u'earliest_cr_line', u'inq_last_6mths', u'mths_since_last_delinq',
#        u'mths_since_last_record', u'open_acc', u'pub_rec', u'revol_bal',
#        u'revol_util', u'total_acc', u'initial_list_status', u'out_prncp',
#        u'out_prncp_inv', u'total_pymnt', u'total_pymnt_inv',
#        u'total_rec_prncp', u'total_rec_int', u'total_rec_late_fee',
#        u'recoveries', u'collection_recovery_fee', u'last_pymnt_d',
#        u'last_pymnt_amnt', u'next_pymnt_d', u'last_credit_pull_d',
#        u'collections_12_mths_ex_med', u'mths_since_last_major_derog',
# ...

# %%
len(df.columns)
# Out:
# 73

# %%
np.unique(df[['grade','sub_grade']])
# Out:
# array(['A', 'A1', 'A2', 'A3', 'A4', 'A5', 'B', 'B1', 'B2', 'B3', 'B4',
#        'B5', 'C', 'C1', 'C2', 'C3', 'C4', 'C5', 'D', 'D1', 'D2', 'D3',
#        'D4', 'D5', 'E', 'E1', 'E2', 'E3', 'E4', 'E5', 'F', 'F1', 'F2',
#        'F3', 'F4', 'F5', 'G', 'G1', 'G2', 'G3', 'G4', 'G5'], dtype=object)

# %%
df['sub_grade'].unique()
# Out:
# array(['B2', 'C4', 'C5', 'C1', 'B5', 'A4', 'E1', 'F2', 'C3', 'B1', 'D1',
#        'A1', 'B3', 'B4', 'C2', 'D2', 'A3', 'A5', 'D5', 'A2', 'E4', 'D3',
#        'D4', 'F3', 'E3', 'F4', 'F1', 'E5', 'G4', 'E2', 'G3', 'G2', 'G1',
#        'F5', 'G5'], dtype=object)

# %%
df['policy_code'].unique()
# Out:
# array([ 1.])

# %%
df['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
df['issue_d'].unique()
# Out:
# array(['Dec-2011', 'Nov-2011', 'Oct-2011', 'Sep-2011', 'Aug-2011',
#        'Jul-2011', 'Jun-2011', 'May-2011', 'Apr-2011', 'Mar-2011',
#        'Feb-2011', 'Jan-2011', 'Dec-2010', 'Nov-2010', 'Oct-2010',
#        'Sep-2010', 'Aug-2010', 'Jul-2010', 'Jun-2010', 'May-2010',
#        'Apr-2010', 'Mar-2010', 'Feb-2010', 'Jan-2010', 'Dec-2009',
#        'Nov-2009', 'Oct-2009', 'Sep-2009', 'Aug-2009', 'Jul-2009',
#        'Jun-2009', 'May-2009', 'Apr-2009', 'Mar-2009', 'Feb-2009',
#        'Jan-2009', 'Dec-2008', 'Nov-2008', 'Oct-2008', 'Sep-2008',
#        'Aug-2008', 'Jul-2008', 'Jun-2008', 'May-2008', 'Apr-2008',
#        'Mar-2008', 'Feb-2008', 'Jan-2008', 'Dec-2007', 'Nov-2007',
#        'Oct-2007', 'Sep-2007', 'Aug-2007', 'Jul-2007', 'Jun-2007',
#        'Dec-2013', 'Nov-2013', 'Oct-2013', 'Sep-2013', 'Aug-2013',
#        'Jul-2013', 'Jun-2013', 'May-2013', 'Apr-2013', 'Mar-2013',
#        'Feb-2013', 'Jan-2013', 'Dec-2012', 'Nov-2012', 'Oct-2012',
# ...

# %%
df['pymnt_plan'].unique()
# Out:
# array(['n', 'y'], dtype=object)

# %%
df['verification_status'].unique()
# Out:
# array(['Verified', 'Source Verified', 'Not Verified'], dtype=object)

# %%
df['loan_amnt'].unique()
# Out:
# array([  5000.,   2500.,   2400., ...,  32925.,  32825.,  32575.])

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', 'Issued'], dtype=object)
